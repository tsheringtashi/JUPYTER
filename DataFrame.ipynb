# %%
# dataframe
# pivot table
# tolist
# Truncate
# loc and iloc

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas import DataFrame, Series, read_csv
# %matplotlib inline

# %%
sales_filepath = '../DATAjupyter/Superstore-Sales.csv'

# %%
# parse_date will make 1/1/2021 to 2021-01-01 a proper date format.
sales = read_csv(sales_filepath,encoding= 'unicode_escape', parse_dates = ["Ship Date"])#.dropna(how ="all")

sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8397 entries, 0 to 8396
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Row ID                8397 non-null   int64
#  1   Order ID              8397 non-null   int64
#  2   Order Date            8397 non-null   object
#  3   Order Priority        8397 non-null   object
#  4   Order Quantity        8397 non-null   int64
#  5   Sales                 8397 non-null   float64
#  6   Discount              8397 non-null   float64
#  7   Ship Mode             8397 non-null   object
#  8   Profit                8397 non-null   float64
#  9   Unit Price            8397 non-null   float64
#  10  Shipping Cost         8397 non-null   float64
#  11  Customer Name         8397 non-null   object
#  12  Province              8397 non-null   object
#  13  Region                8397 non-null   object
#  14  Customer Segment      8397 non-null   object
#  15  Product Category      8397 non-null   object
#  16  Product Sub-Category  8397 non-null   object
#  17  Product Name          8397 non-null   object
#  18  Product Container     8397 non-null   object
#  19  Product Base Margin   8334 non-null   float64
#  20  Ship Date             8397 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(6), int64(3), object(11)
# memory usage: 1.3+ MB

# %%
sales.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Order Priority', 'Order Quantity',
#        'Sales', 'Discount', 'Ship Mode', 'Profit', 'Unit Price',
#        'Shipping Cost', 'Customer Name', 'Province', 'Region',
#        'Customer Segment', 'Product Category', 'Product Sub-Category',
#        'Product Name', 'Product Container', 'Product Base Margin',
#        'Ship Date'],
#       dtype='object')

# %%
renamed =  sales.rename(columns = {'Row ID':'Row_ID', 'Order ID':'Order_ID','Order Date':'Order_Date','Order Priority':'Order_Priority', 'Order Quantity':'Order_Quantity','Ship Mode':'Ship_Mode', 'Unit Price':'Unit_Price',
       'Shipping Cost':'Shipping_Cost', 'Customer Name':'Customer_Name', 'Customer Segment':'Customer_Segment', 'Product Category':'Product_Category', 'Product Sub-Category':'Product_Sub-Category',
       'Product Name':'Product_Name', 'Product Container':'Product_Container', 'Product Base Margin':'Product_Base_Margin',
       'Ship Date': 'Ship_Date' }, inplace = True)

# %%
# better way to rename by looping and replace.


#for x in sales.columns:
 #   replace(' ', '_')

# %%
sales.head(2)
# Out:
#    Row_ID  Order_ID  Order_Date Order_Priority  Order_Quantity     Sales  \
# 0       1         3  10/13/2010            Low               6    261.54
# 1      49       293   10/1/2012           High              49  10123.02
#
#    Discount       Ship_Mode  Profit  Unit_Price  ...       Customer_Name  \
# 0      0.04     Regular Air -213.25       38.94  ...  Muhammed MacIntyre
# 1      0.07  Delivery Truck  457.81      208.16  ...        Barry French
#
#   Province   Region Customer_Segment Product_Category    Product_Sub-Category  \
# 0  Nunavut  Nunavut   Small Business  Office Supplies  Storage & Organization
# 1  Nunavut  Nunavut         Consumer  Office Supplies              Appliances
#
#                                         Product_Name Product_Container  \
# 0   Eldon Base for stackable storage shelf, platinum         Large Box
# 1  1.7 Cubic Foot Compact "Cube" Office Refrigera...        Jumbo Drum
#
#   Product_Base_Margin  Ship_Date
# 0                0.80 2010-10-20
# 1                0.58 2012-10-02
#
# [2 rows x 21 columns]

# %% [markdown]
# ### pivot table

# %%
sales.pivot(index ='Row_ID', columns ='Region', values ='Sales')
# Out:
# Region  Atlantic  Northwest Territories  Nunavut  Ontario     Prarie  Quebec  \
# Row_ID
# 1            NaN                    NaN   261.54      NaN        NaN     NaN
# 2            NaN                    NaN      NaN      NaN        NaN     NaN
# 3            NaN                    NaN      NaN      NaN        NaN     NaN
# 4            NaN                    NaN      NaN      NaN        NaN     NaN
# 5            NaN                    NaN      NaN      NaN        NaN     NaN
# ...          ...                    ...      ...      ...        ...     ...
# 8395         NaN                    NaN      NaN      NaN        NaN     NaN
# 8396         NaN                    NaN      NaN      NaN        NaN     NaN
# 8397         NaN                    NaN      NaN      NaN        NaN     NaN
# 8398         NaN                    NaN      NaN      NaN  11039.750     NaN
# 8399         NaN                    NaN      NaN      NaN   4982.944     NaN
#
# Region       West  Yukon
# Row_ID
# 1             NaN    NaN
# 2          6.9300    NaN
# 3       2808.0800    NaN
# 4       1761.4000    NaN
# 5        160.2335    NaN
# ...           ...    ...
# 8395     437.7700    NaN
# 8396     514.8600    NaN
# 8397     356.2700    NaN
# 8398          NaN    NaN
# 8399          NaN    NaN
#
# [8397 rows x 8 columns]

# %%
sales.pivot_table(index=['Customer_Segment', 'Region'], columns = "Product_Category", values= 'Profit', aggfunc ='sum')
# Out:
# Product_Category                        Furniture  Office Supplies  Technology
# Customer_Segment Region
# Consumer         Atlantic                 3407.10         18445.24    63232.62
#                  Northwest Territories   -1557.90           343.53    12434.54
#                  Nunavut                  3428.65           612.44         NaN
#                  Ontario                   392.46          8203.57    16883.48
#                  Prarie                   6182.58         24562.15    29838.04
#                  Quebec                   4757.14         12793.00    14154.17
#                  West                    26498.67         14372.88    27115.06
#                  Yukon                    -380.44          9199.48    -6958.52
# Corporate        Atlantic                -3338.83         23865.22    23575.19
#                  Northwest Territories    6626.43         10721.62    26229.08
#                  Nunavut                  -337.46         -2739.07     1723.72
#                  Ontario                  1257.87         55970.31    79111.51
#                  Prarie                  12835.45         22447.97   133728.25
#                  Quebec                   -919.65         15826.73    38006.30
#                  West                     9619.56         67720.17    62505.06
#                  Yukon                   -3735.29          9224.43     9821.43
# Home Office      Atlantic                11753.71          6536.52    44905.96
#                  Northwest Territories   -6867.60          5761.89    11630.53
#                  Nunavut                   387.69           -92.45      762.53
#                  Ontario                 23923.74         62496.03    42760.39
#                  Prarie                   9273.57         19714.54    26218.03
#                  Quebec                  -3603.31          7153.41    21253.34
#                  West                   -19312.85         20420.77     6557.53
#                  Yukon                    8424.25          -845.06    19140.87
# Small Business   Atlantic                 3523.67         18123.49    24930.77
#                  Northwest Territories    9250.31         20167.02     5913.63
#                  Nunavut                      NaN          -994.02         NaN
#                  Ontario                 -5687.16         26542.85    35013.49
#                  Prarie                   2259.62         16535.04    17564.88
#                  Quebec                   -994.95          7209.03    24791.44
#                  West                    14119.26         14153.03    53239.47
#                  Yukon                    6246.74          3480.59    20230.73

# %%
df_dict =  pd.DataFrame({
    'id': [100,200,300], 'color': ['red','blue','green']
}, columns =['id','color'], index = ['a','b','c'])

df_dict
# Out:
#     id  color
# a  100    red
# b  200   blue
# c  300  green

# %%
# note that each inner bracket treat as rows.
df_list = pd.DataFrame([[100, 'red'], [200,'blue'],[300,'green']], columns= ['id','colour'])
df_list
# Out:
#     id colour
# 0  100    red
# 1  200   blue
# 2  300  green

# %%
# compare list with dic
print(df_dict)
print()
print(df_list)
# Out:
#     id  color
# a  100    red
# b  200   blue
# c  300  green
#
#     id colour
# 0  100    red
# 1  200   blue
# 2  300  green

# %%
sales.dtypes.value_counts()
# Out:
# object            10
# float64            6
# int64              3
# datetime64[ns]     1
# category           1
# dtype: int64

# %%
sales.index
# Out:
# RangeIndex(start=0, stop=8397, step=1)

# %%
# Create a list of province.
sales['Province'].tolist()[1:10]
# Out:
# ['Nunavut',
#  'Nunavut',
#  'Nunavut',
#  'Nunavut',
#  'Nunavut',
#  'Nunavut',
#  'Nunavut',
#  'Nunavut',
#  'Nunavut']

# %%
sales['Province'].to_frame()
# Out:
#      Province
# 0     Nunavut
# 1     Nunavut
# 2     Nunavut
# 3     Nunavut
# 4     Nunavut
# ...       ...
# 8392  Alberta
# 8393  Alberta
# 8394  Alberta
# 8395  Alberta
# 8396  Alberta
#
# [8397 rows x 1 columns]

# %%
 ",".join(str(x) for x in sales['Province'])
# Out:
# 'Nunavut,Nunavut,Nunavut,Nunavut,Nunavut,Nunavut,Nunavut,Nunavut,Nunavut,Nunavut,Nunavut,Nunavut,Nunavut,Nunavut,Nunavut,Nunavut,Nunavut,Nunavut,Nunavut,Nunavut,Nunavut,Nunavut,Nunavut,Nunavut,Nunavut,Nunavut,Nunavut,Nunavut,Nunavut,Nunavut,Nunavut,Nunavut,Nunavut,Nunavut,Nunavut,Nunavut,Nunavut,Nunavut,Nunavut,Nunavut,Nunavut,Nunavut,Nunavut,Nunavut,Nunavut,Nunavut,Nunavut,Nunavut,Nunavut,Nunavut,Nunavut,Nunavut,Nunavut,Nunavut,Nunavut,Nunavut,Nunavut,Nunavut,Nunavut,Nunavut,Nunavut,Nunavut,Nunavut,Nunavut,Nunavut,Nunavut,Nunavut,Nunavut,Nunavut,Nunavut,Nunavut,Nunavut,Nunavut,Nunavut,Nunavut,Nunavut,Nunavut,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territories,Northwest Territo ...

# %% [markdown]
# ### Sample

# %%
sales.head()

# %%
# axis = 'rows' will select 5 rows randomly.

sales.sample(5, axis = "rows")

# %%
# axis = 'columns' will select 5 columns randomly.

sales.sample(5, axis = "columns")

# %% [markdown]
# ### Truncate

# %%
sales.truncate(before = 2000, after = 2010, axis ='rows')
# Out:
#       Row_ID  Order_ID Order_Date Order_Priority  Order_Quantity    Sales  \
# 2000     751      5381  1/28/2010            Low              27    63.87
# 2001     759      5444  3/17/2011       Critical               2   885.94
# 2002     785      5601   1/5/2012           High              10   120.53
# 2003     802      5760  5/24/2009  Not Specified              34  5261.73
# 2004     896      6438  5/16/2010  Not Specified               7    75.72
# 2005     897      6438  5/16/2010  Not Specified              38   225.21
# 2006     917      6592  12/1/2009            Low              29   194.29
# 2007     918      6592  12/1/2009            Low              33  1621.10
# 2008     933      6755   5/1/2011           High              20   156.47
# 2009     957      6918   7/1/2011       Critical              38  1559.50
# 2010    1060      7841  5/20/2012  Not Specified              21  1002.77
#
#       Discount       Ship_Mode   Profit  Unit_Price  ...   Customer_Name  \
# 2000      0.09     Regular Air  -149.93        2.18  ...   Edward Nazzal
# 2001      0.08     Regular Air -2024.08      449.99  ...  Frank Carlisle
# 2002      0.10     Regular Air    49.26       12.22  ...     Gary Hansen
# 2003      0.05  Delivery Truck   650.30      150.98  ...  Nancy Lomonaco
# 2004      0.02     Regular Air    20.29        9.77  ...   Anna Haberlin
# 2005      0.06     Regular Air   -66.16        5.98  ...   Anna Haberlin
# 2006      0.09     Regular Air  -177.17        6.84  ...    Tamara Chand
# 2007      0.07     Express Air  -971.36       48.91  ...    Tamara Chand
# 2008      0.01     Regular Air   -39.23        7.10  ...   Kelly Lampkin
# 2009      0.01     Regular Air   515.83       39.48  ...   Erin Ashbrook
# 2010      0.07     Regular Air   295.60       49.34  ...     Darren Budd
#
#      Province   Region Customer_Segment Product_Category  \
# 2000  Ontario  Ontario      Home Office  Office Supplies
# 2001  Ontario  Ontario   Small Business       Technology
# 2002  Ontario  Ontario         Consumer        Furniture
# 2003  Ontario  Ontario      Home Office        Furniture
# 2004  Ontario  Ontario        Corporate        Furniture
# 2005  Ontario  Ontario        Corporate  Office Supplies
# 2006  Ontario  Ontario         Consumer  Office Supplies
# 2007  Ontario  Ontario         Consumer  Office Supplies
# 2008  Ontario  Ontario      Home Office  Office Supplies
# 2009  Ontario  Ontario         Consumer       Technology
# 2010  Ontario  Ontario         Consumer        Furniture
#
#                 Product_Sub-Category  \
# 2000                           Paper
# 2001                 Copiers and Fax
# 2002              Office Furnishings
# 2003              Chairs & Chairmats
# 2004              Office Furnishings
# 2005                           Paper
# 2006   Scissors, Rulers and Trimmers
# 2007          Storage & Organization
# 2008  Binders and Binder Accessories
# 2009            Computer Peripherals
# 2010              Office Furnishings
#
#                                            Product_Name Product_Container  \
# 2000     Ampad® Evidence® Wirebond Steno Books, 6" x 9"          Wrap Bag
# 2001                                 Canon PC940 Copier         Large Box
# 2002                            Aluminum Document Frame        Small Pack
# 2003      Global Airflow Leather Mesh Back Chair, Black        Jumbo Drum
# 2004                              DAX Solid Wood Frames        Medium Box
# 2005                                         Xerox 1992         Small Box
# 2006  Acme Design Line 8" Stainless Steel Bent Sciss...        Small Pack
# 2007                        Tennsco Industrial Shelving         Large Box
# 2008        Wilson Jones Hanging View Binder, White, 1"         Small Box
# 2009         80 Minute CD-R Spindle, 100/Pack - Staples        Small Pack
# 2010  Electrix Fluorescent Magnifier Lamps & Weighte...         Large Box
#
#      Product_Base_Margin  Ship_Date
# 2000                0.38 2010-02-04
# 2001                0.52 2011-03-19
# 2002                0.55 2012-01-06
# 2003                0.55 2009-05-25
# 2004                0.48 2010-05-16
# 2005                0.36 2010-05-17
# 2006                0.58 2009-12-08
# 2007                0.83 2009-12-03
# 2008                0.39 2011-05-03
# 2009                0.54 2011-07-03
# 2010                0.57 2012-05-22
#
# [11 rows x 21 columns]

# %%
sales.truncate(before = "Order_Date", after = "Profit", axis ="columns")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-164adf54f010> in <module>
# ----> 1 sales.truncate(before = "Order_Date", after = "Profit", axis ="columns")
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in truncate(self, before, after, axis, copy)
#    9396         # Check that index is sorted
#    9397         if not ax.is_monotonic_increasing and not ax.is_monotonic_decreasing:
# -> 9398             raise ValueError("truncate requires a sorted index")
#    9399
#    9400         # if we have a date index, convert to dates, otherwise
#
# ValueError: truncate requires a sorted index

# %% [markdown]
# ### LOC and ILOC
# - LOC is location of data on dataframe. it is label.
# - ILOC meand integer location meaning data on the dataframe is found out by integer rows and columns.
# - pd.loc is wrong as it is dataframe method.
# - df.loc is right.

# %%
sales.head()
# Out:
#    Row_ID  Order_ID  Order_Date Order_Priority  Order_Quantity       Sales  \
# 0       1         3  10/13/2010            Low               6    261.5400
# 1      49       293   10/1/2012           High              49  10123.0200
# 2      50       293   10/1/2012           High              27    244.5700
# 3      80       483   7/10/2011           High              30   4965.7595
# 4      85       515   8/28/2010  Not Specified              19    394.2700
#
#    Discount       Ship_Mode   Profit  Unit_Price  ...       Customer_Name  \
# 0      0.04     Regular Air  -213.25       38.94  ...  Muhammed MacIntyre
# 1      0.07  Delivery Truck   457.81      208.16  ...        Barry French
# 2      0.01     Regular Air    46.71        8.69  ...        Barry French
# 3      0.08     Regular Air  1198.97      195.99  ...       Clay Rozendal
# 4      0.08     Regular Air    30.94       21.78  ...      Carlos Soltero
#
#   Province   Region Customer_Segment Product_Category  \
# 0  Nunavut  Nunavut   Small Business  Office Supplies
# 1  Nunavut  Nunavut         Consumer  Office Supplies
# 2  Nunavut  Nunavut         Consumer  Office Supplies
# 3  Nunavut  Nunavut        Corporate       Technology
# 4  Nunavut  Nunavut         Consumer  Office Supplies
#
#              Product_Sub-Category  \
# 0          Storage & Organization
# 1                      Appliances
# 2  Binders and Binder Accessories
# 3    Telephones and Communication
# 4                      Appliances
#
#                                         Product_Name Product_Container  \
# 0   Eldon Base for stackable storage shelf, platinum         Large Box
# 1  1.7 Cubic Foot Compact "Cube" Office Refrigera...        Jumbo Drum
# 2   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl         Small Box
# 3                                               R380         Small Box
# 4                           Holmes HEPA Air Purifier        Medium Box
#
#   Product_Base_Margin  Ship_Date
# 0                0.80 2010-10-20
# 1                0.58 2012-10-02
# 2                0.39 2012-10-03
# 3                0.58 2011-07-12
# 4                0.50 2010-08-30
#
# [5 rows x 21 columns]

# %%
sales.iloc[0:3] # use like .head()
# Out:
#    Row_ID  Order_ID  Order_Date Order_Priority  Order_Quantity     Sales  \
# 0       1         3  10/13/2010            Low               6    261.54
# 1      49       293   10/1/2012           High              49  10123.02
# 2      50       293   10/1/2012           High              27    244.57
#
#    Discount       Ship_Mode  Profit  Unit_Price  ...       Customer_Name  \
# 0      0.04     Regular Air -213.25       38.94  ...  Muhammed MacIntyre
# 1      0.07  Delivery Truck  457.81      208.16  ...        Barry French
# 2      0.01     Regular Air   46.71        8.69  ...        Barry French
#
#   Province   Region Customer_Segment Product_Category  \
# 0  Nunavut  Nunavut   Small Business  Office Supplies
# 1  Nunavut  Nunavut         Consumer  Office Supplies
# 2  Nunavut  Nunavut         Consumer  Office Supplies
#
#              Product_Sub-Category  \
# 0          Storage & Organization
# 1                      Appliances
# 2  Binders and Binder Accessories
#
#                                         Product_Name Product_Container  \
# 0   Eldon Base for stackable storage shelf, platinum         Large Box
# 1  1.7 Cubic Foot Compact "Cube" Office Refrigera...        Jumbo Drum
# 2   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl         Small Box
#
#   Product_Base_Margin  Ship_Date
# 0                0.80 2010-10-20
# 1                0.58 2012-10-02
# 2                0.39 2012-10-03
#
# [3 rows x 21 columns]

# %%
sales.loc[sales["Order_Priority"] == "Low"]
# Out:
#       Row_ID  Order_ID  Order_Date Order_Priority  Order_Quantity      Sales  \
# 0          1         3  10/13/2010            Low               6   261.5400
# 9        107       678   2/26/2010            Low              44   228.4100
# 17       203      1344   4/15/2012            Low              15   834.9040
# 18       204      1344   4/15/2012            Low              18  2480.9205
# 21       229      1539    3/9/2011            Low              33   511.8300
# ...      ...       ...         ...            ...             ...        ...
# 8379    1219      8961   6/28/2011            Low              48  4644.8700
# 8380    1617     11712   4/26/2009            Low               9    38.9600
# 8381    2082     14883    5/6/2011            Low              38   978.4000
# 8382    2083     14883    5/6/2011            Low              47  5126.4180
# 8390    7396     52706    7/9/2012            Low              34  1041.6600
#
#       Discount       Ship_Mode   Profit  Unit_Price  ...       Customer_Name  \
# 0         0.04     Regular Air  -213.25       38.94  ...  Muhammed MacIntyre
# 9         0.07     Regular Air  -226.36        4.98  ...     Dorothy Badders
# 17        0.06     Regular Air   -11.68       65.99  ...         Jim Radford
# 18        0.01     Regular Air   313.58      155.99  ...         Jim Radford
# 21        0.10     Regular Air  -172.88       15.99  ...         Carl Ludwig
# ...        ...             ...      ...         ...  ...                 ...
# 8379      0.08  Delivery Truck -1291.39      100.80  ...      Jessica Myrick
# 8380      0.06     Regular Air     0.37        4.28  ...      Nicole Brennan
# 8381      0.07  Delivery Truck  -211.58       25.98  ...       Jason Fortune
# 8382      0.03     Regular Air  1557.64      125.99  ...       Jason Fortune
# 8390      0.02     Express Air   480.53       28.53  ...        Harry Greene
#
#      Province   Region Customer_Segment Product_Category  \
# 0     Nunavut  Nunavut   Small Business  Office Supplies
# 9     Nunavut  Nunavut      Home Office  Office Supplies
# 17    Nunavut  Nunavut        Corporate       Technology
# 18    Nunavut  Nunavut        Corporate       Technology
# 21    Nunavut  Nunavut        Corporate  Office Supplies
# ...       ...      ...              ...              ...
# 8379  Alberta     West   Small Business        Furniture
# 8380  Alberta     West         Consumer  Office Supplies
# 8381  Alberta     West        Corporate        Furniture
# 8382  Alberta     West        Corporate       Technology
# 8390  Alberta     West        Corporate  Office Supplies
#
#                 Product_Sub-Category  \
# 0             Storage & Organization
# 9                              Paper
# 17      Telephones and Communication
# 18      Telephones and Communication
# 21    Binders and Binder Accessories
# ...                              ...
# 8379                          Tables
# 8380             Pens & Art Supplies
# 8381              Chairs & Chairmats
# 8382    Telephones and Communication
# 8390  Binders and Binder Accessories
#
#                                            Product_Name Product_Container  \
# 0      Eldon Base for stackable storage shelf, platinum         Large Box
# 9                                             Xerox 198         Small Box
# 17                                                 g520         Small Box
# 18                                               LX 788         Small Box
# 21    GBC Pre-Punched Binding Paper, Plastic, White,...         Small Box
# ...                                                 ...               ...
# 8379  Barricks 18" x 48" Non-Folding Utility Table w...        Jumbo Drum
# 8380                                         Newell 336          Wrap Bag
# 8381             Global Stack Chair without Arms, Black        Jumbo Drum
# 8382                                              i2000         Small Box
# 8390                        Lock-Up Easel 'Spel-Binder'         Small Box
#
#      Product_Base_Margin  Ship_Date
# 0                   0.80 2010-10-20
# 9                   0.38 2010-02-26
# 17                  0.59 2012-04-22
# 18                  0.58 2012-04-19
# 21                  0.37 2011-03-11
# ...                  ...        ...
# 8379                0.59 2011-07-03
# 8380                0.56 2009-04-28
# 8381                0.60 2011-05-11
# 8382                0.60 2011-05-15
# 8390                0.38 2012-07-16
#
# [1720 rows x 21 columns]

# %%
sales.head()
# Out:
#    Row_ID  Order_ID  Order_Date Order_Priority  Order_Quantity       Sales  \
# 0       1         3  10/13/2010            Low               6    261.5400
# 1      49       293   10/1/2012           High              49  10123.0200
# 2      50       293   10/1/2012           High              27    244.5700
# 3      80       483   7/10/2011           High              30   4965.7595
# 4      85       515   8/28/2010  Not Specified              19    394.2700
#
#    Discount       Ship_Mode   Profit  Unit_Price  ...       Customer_Name  \
# 0      0.04     Regular Air  -213.25       38.94  ...  Muhammed MacIntyre
# 1      0.07  Delivery Truck   457.81      208.16  ...        Barry French
# 2      0.01     Regular Air    46.71        8.69  ...        Barry French
# 3      0.08     Regular Air  1198.97      195.99  ...       Clay Rozendal
# 4      0.08     Regular Air    30.94       21.78  ...      Carlos Soltero
#
#   Province   Region Customer_Segment Product_Category  \
# 0  Nunavut  Nunavut   Small Business  Office Supplies
# 1  Nunavut  Nunavut         Consumer  Office Supplies
# 2  Nunavut  Nunavut         Consumer  Office Supplies
# 3  Nunavut  Nunavut        Corporate       Technology
# 4  Nunavut  Nunavut         Consumer  Office Supplies
#
#              Product_Sub-Category  \
# 0          Storage & Organization
# 1                      Appliances
# 2  Binders and Binder Accessories
# 3    Telephones and Communication
# 4                      Appliances
#
#                                         Product_Name Product_Container  \
# 0   Eldon Base for stackable storage shelf, platinum         Large Box
# 1  1.7 Cubic Foot Compact "Cube" Office Refrigera...        Jumbo Drum
# 2   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl         Small Box
# 3                                               R380         Small Box
# 4                           Holmes HEPA Air Purifier        Medium Box
#
#   Product_Base_Margin  Ship_Date
# 0                0.80 2010-10-20
# 1                0.58 2012-10-02
# 2                0.39 2012-10-03
# 3                0.58 2011-07-12
# 4                0.50 2010-08-30
#
# [5 rows x 21 columns]
